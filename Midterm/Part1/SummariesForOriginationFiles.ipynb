# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
origData = pd.read_csv('C:\\Users\\pragati\\Desktop\\ADS Midterm\\jupyterOrigSummaries', index_col=0)
origData
# Out:
#       Loan Count  WAV Credit Score  Total Original UPB  Average Original UPB  \
# year
# 2016     12500.0        749.489127        2.860699e+09             228855.92
# 2015     50000.0        752.396318        1.146816e+10             229363.16
# 2014     50000.0        751.913749        1.099329e+10             219865.72
# 2013     50000.0        758.730180        1.087998e+10             217599.68
# 2012     50000.0        767.030326        1.113358e+10             222671.62
# 2011     50000.0        764.325557        1.085397e+10             217079.46
# 2010     50000.0        763.310383        1.041944e+10             208388.82
# 2009     50000.0        762.837070        1.068599e+10             213719.74
# 2008     50000.0        743.054029        1.019909e+10             203981.86
# 2007     50000.0        724.877342        9.188208e+09             183764.16
# 2006     50000.0        723.936388        8.979629e+09             179592.58
# ...

# %%
loandf=origData.filter(['year','Loan Count'], axis=1)
LoanCount_plot = loandf.plot(kind='bar',title="Loan count over years")

WAVCreditScoredf=origData.filter(['year','WAV Credit Score'], axis=1)
WAVCreditScore_plot = WAVCreditScoredf.plot(kind='bar',title="WAV Credit Score over years")

AvgUPBdf=origData.filter(['year','Average Original UPB'], axis=1)
AvgUPBdf_plot = AvgUPBdf.plot(kind='bar',title="Average Original UPB over years")

WAVOriginalCLTVdf=origData.filter(['year','WAV Original CLTV'], axis=1)
WAVOriginalCLTVdf_plot = WAVOriginalCLTVdf.plot(kind='line',title="WAV Original CLTV over years")

WAVOriginalLTVdf=origData.filter(['year','WAV Original LTV'], axis=1)
WAVOriginalLTVdf_plot = WAVOriginalLTVdf.plot(kind='line',title="WAV Original LTV over years")

WAVOriginalDTIdf=origData.filter(['year','WAV Original DTI'], axis=1)
WAVOriginalDTIdf_plot = WAVOriginalDTIdf.plot(kind='line',title="WAV Original DTI over years")
